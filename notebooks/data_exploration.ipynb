# %%
import json

data = []
with open(r"D:\Karm\Internships\simllp\research-engineering-intern-assignment\data\data.jsonl", "r", encoding="utf-8") as f:
    for line in f:
        data.append(json.loads(line))
